# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("dataset/irrigation_prediction.csv")

# Drop unnecessary columns
columns_to_drop = ['Soil_pH', 'Organic_Carbon', 'Electrical_Conductivity', 'Crop_Growth_Stage', 'Irrigation_Type', 'Water_Source', 'Mulching_Used', 'Region']
df = df.drop(columns=columns_to_drop, errors='ignore')

print("DataFrame columns after dropping:", df.columns.tolist())
df.head()
# Out:
# DataFrame columns after dropping: ['Soil_Type', 'Soil_Moisture', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Season', 'Field_Area_hectare', 'Previous_Irrigation_mm', 'Irrigation_Need']
#   Soil_Type  Soil_Moisture  Temperature_C  Humidity  Rainfall_mm  \
# 0      Clay          36.48          21.90     31.19      1167.70
# 1      Silt          50.56          36.50     26.01       831.28
# 2     Sandy          40.07          41.83     76.41      1844.45
# 3      Clay          12.75          37.22     43.32       306.26
# 4      Clay          18.58          22.38     86.44      1875.63
#
#    Sunlight_Hours  Wind_Speed_kmh Crop_Type  Season  Field_Area_hectare  \
# 0            4.01            1.97     Wheat    Rabi                4.73
# 1           10.72           16.82     Maize    Zaid               12.22
# 2            7.75           19.03    Cotton    Rabi                5.52
# ...

# %%
# Encode categorical variables
le_soil = LabelEncoder()
df['Soil_Type_enc'] = le_soil.fit_transform(df['Soil_Type'])

le_crop = LabelEncoder()
df['Crop_Type_enc'] = le_crop.fit_transform(df['Crop_Type'])

le_season = LabelEncoder()
df['Season_enc'] = le_season.fit_transform(df['Season'])

le_target = LabelEncoder()
df['Irrigation_Need_enc'] = le_target.fit_transform(df['Irrigation_Need'])

# Features and target
X = df[['Soil_Type_enc', 'Crop_Type_enc', 'Season_enc',
        'Soil_Moisture', 'Temperature_C', 'Humidity', 'Rainfall_mm',
        'Sunlight_Hours', 'Wind_Speed_kmh', 'Field_Area_hectare', 'Previous_Irrigation_mm']].values
y = df['Irrigation_Need_enc'].values  # No reshape for classification

# Scale features
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# No scaling for target in classification

# %%
class IrrigationDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
train_dataset = IrrigationDataset(X_train, y_train)
test_dataset = IrrigationDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64)

# %%
class IrrigationModel(nn.Module):
    def __init__(self, input_dim, num_classes):
        super(IrrigationModel, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )
    
    def forward(self, x):
        return self.model(x)

input_dim = X_train.shape[1]
num_classes = len(le_target.classes_)
model = IrrigationModel(input_dim, num_classes)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50

for epoch in range(num_epochs):
    model.train()
    running_loss = 0
    for features, target in train_loader:
        optimizer.zero_grad()
        outputs = model(features)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch [{epoch+1}/{num_epochs}] Loss: {running_loss/len(train_loader):.4f}")
# Out:
# Epoch [1/50] Loss: 0.7535
# Epoch [2/50] Loss: 0.6417
# Epoch [3/50] Loss: 0.6279
# Epoch [4/50] Loss: 0.6094
# Epoch [5/50] Loss: 0.6005
# Epoch [6/50] Loss: 0.5880
# Epoch [7/50] Loss: 0.5792
# Epoch [8/50] Loss: 0.5739
# Epoch [9/50] Loss: 0.5685
# Epoch [10/50] Loss: 0.5642
# Epoch [11/50] Loss: 0.5574
# Epoch [12/50] Loss: 0.5546
# Epoch [13/50] Loss: 0.5495
# Epoch [14/50] Loss: 0.5429
# Epoch [15/50] Loss: 0.5384
# Epoch [16/50] Loss: 0.5358
# Epoch [17/50] Loss: 0.5297
# Epoch [18/50] Loss: 0.5279
# Epoch [19/50] Loss: 0.5222
# Epoch [20/50] Loss: 0.5169
# Epoch [21/50] Loss: 0.5155
# Epoch [22/50] Loss: 0.5091
# Epoch [23/50] Loss: 0.5083
# Epoch [24/50] Loss: 0.5068
# Epoch [25/50] Loss: 0.4979
# Epoch [26/50] Loss: 0.4940
# Epoch [27/50] Loss: 0.4890
# Epoch [28/50] Loss: 0.4870
# Epoch [29/50] Loss: 0.4828
# Epoch [30/50] Loss: 0.4777
# Epoch [31/50] Loss: 0.4777
# Epoch [32/50] Loss: 0.4693
# Epoch [33/50] Loss: 0.4678
# Epoch [34/50] Loss: 0.4625
# ...

# %%
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for features, target in test_loader:
        outputs = model(features)
        _, predicted = torch.max(outputs.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
    
    accuracy = correct / total
    print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# Test Accuracy: 0.64

# %%
torch.save(model.state_dict(), "irrigation_model.pt")
import joblib
joblib.dump(scaler_X, "scaler_X.pkl")

# Save LabelEncoders
joblib.dump(le_soil, "le_soil.pkl")
joblib.dump(le_crop, "le_crop.pkl")
joblib.dump(le_season, "le_season.pkl")
joblib.dump(le_target, "le_target.pkl")

print("✅ Model, scalers, and encoders saved!")
# Out:
# ✅ Model, scalers, and encoders saved!

# %%
# Assuming df is already loaded and columns renamed as in the notebook
unique_crop_types = df['Crop_Type'].unique()
unique_soil_types = df['Soil_Type'].unique()

print("Unique Crop Types:", unique_crop_types)
print("Unique Soil Types:", unique_soil_types)
# Out:
# Unique Crop Types: ['Wheat' 'Maize' 'Cotton' 'Rice' 'Sugarcane' 'Potato']
# Unique Soil Types: ['Clay' 'Silt' 'Sandy' 'Loamy']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
